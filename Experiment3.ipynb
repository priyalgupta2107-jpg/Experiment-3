# %% [markdown]
# Priyal Gupta
# PRN: 25070123087
# Aim of Experiment: Study of Tuple in Python

# %%
tpl=(2,True,"priyal")
print(tpl)
# Out:
# (2, True, 'priyal')

# %%
tpl2=("apple","banana","orange")
print(tpl2[1])
print(tpl2[-2])
# Out:
# banana
# banana

# %%
tpl3=("apple","banana","orange")
tpl3[1]="kiwi"
print(tpl3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-22768901.py in <cell line: 0>()
#       1 tpl3=("apple","banana","orange")
# ----> 2 tpl3[1]="kiwi"
#       3 print(tpl3)
#
# TypeError: 'tuple' object does not support item assignment

# %%
tpl5=(10,)*5
print(tpl5)
# Out:
# (10, 10, 10, 10, 10)

# %%
tpl6=(10)*5
print(tpl6)
# Out:
# 50

# %%
tpl7=("apple","banana","orange")
print("Before:",id(tpl7))
tpl7+=tpl8
print(tpl7)
print("After:",id(tpl7))
# Out:
# Before: 134875447120192
# ('apple', 'banana', 'orange', 'kiwi')
# After: 134874503721616

# %%
tpl7=["apple","banana","orange"]
print("Before:",id(tpl7))
tpl7+=tpl8
print(tpl7)
print("After:",id(tpl7))
# Out:
# Before: 134874503509632
# ['apple', 'banana', 'orange', 'kiwi']
# After: 134874503509632

# %%
tpl9= (90, 82, 66, 76, 33)
print(max(tpl9))
print(min(tpl9))
print(len(tpl9))
print(sum(tpl9))
print(sum(tpl9)/len(tpl9))
print(sorted(tpl9))
# Out:
# 90
# 33
# 5
# 347
# 69.4
# [33, 66, 76, 82, 90]

# %%
result = ("Maths",86,"A")
print("Subject:",result[0])
print("Marks:",result[1])
print("Grade:",result[2])
#unpacking a tuple
subject,marks,grade = result
print("subject:",subject)
print("marks:",marks)
print("grade:",grade)
#check for distinction
if marks>=75:
  print("Distinction")
# Out:
# Subject: Maths
# Marks: 86
# Grade: A
# subject: Maths
# marks: 86
# grade: A
# Distinction

# %%
attendance = ("P","A","P","P","A","P")
print("Total present days:",attendance.count("P"))
print("Total Absent days:",attendance.count("A"))
if "A" in attendance:
      print("Employee was absent at least once")
# Out:
# Total present days: 4
# Total Absent days: 2
# Employee was absent at least once
